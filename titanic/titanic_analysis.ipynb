# %%
pwd

# %%
import os

# %%
os.chdir('C:\\Users\\augus\\Dev\\Python\\titanic')

# %%
pwd
# Out:
# 'C:\\Users\\augus\\Dev\\Python\\titanic'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D3C1-50E0
#
#  Directory of C:\Users\augus\Dev\Python\titanic
#
# 29-12-2018  05.28 PM    <DIR>          .
# 29-12-2018  05.28 PM    <DIR>          ..
# 20-12-2018  12.08 AM    <DIR>          __pycache__
# 19-12-2018  10.56 PM               266 clean_data.py
# 20-12-2018  05.45 PM             3,258 decision_tree_submission.csv
# 29-12-2018  05.30 PM               294 eval.py
# 19-12-2018  03.43 PM             3,258 gender_submission.csv
# 20-12-2018  05.56 PM             3,258 generalized_decision_tree_submission.csv
# 29-12-2018  05.32 PM             3,258 generalized_poly_decision_tree_submission.csv
# 29-12-2018  05.26 PM             3,258 generalized_poly_decision_tree_submission2.csv
# 20-12-2018  02.14 PM             3,258 logistic_submission.csv
# 20-12-2018  02.13 PM             3,258 logistic_submission.txt
# 09-12-2018  06.46 PM               252 plot.py
# ...

# %%
import pandas as pd
import uti
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('train.csv')
uti.clean(df)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         0
# 1          PC 17599  71.2833   C85         1
# 2  STON/O2. 3101282   7.9250   NaN         0
# 3            113803  53.1000  C123         0
# 4            373450   8.0500   NaN         0

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.339898  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.081163  0.114631
# Age             0.034212 -0.064910 -0.339898 -0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.096688  0.159651
# Embarked       -0.030467  0.106811  0.045702  0.116569 -0.009165 -0.059961
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658 -0.030467
# Survived     0.081629  0.257307  0.106811
# Pclass       0.018443 -0.549500  0.045702
# Sex          0.245489  0.182333  0.116569
# ...

# %%
plt.figure(figsize=(100,100))

# %%
sns.heatmap(df.corr(),annot=True,cmap="RdBu")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         0
# 1          PC 17599  71.2833   C85         1
# 2  STON/O2. 3101282   7.9250   NaN         0
# 3            113803  53.1000  C123         0
# 4            373450   8.0500   NaN         0

# %%
df = df[["PassengerId","Sex","Pclass","Age","SibSp","Parch","Fare","Embarked","Survived"]]

# %%
df.head()
# Out:
#    PassengerId  Sex  Pclass   Age  SibSp  Parch     Fare  Embarked  Survived
# 0            1    0       3  22.0      1      0   7.2500         0         0
# 1            2    1       1  38.0      1      0  71.2833         1         1
# 2            3    1       3  26.0      0      0   7.9250         0         1
# 3            4    1       1  35.0      1      0  53.1000         0         1
# 4            5    0       3  35.0      0      0   8.0500         0         0

# %%
feature = ["PassengerId","Sex","Age","Pclass","SibSp","Parch","Fare","Embarked"]

# %%
X= df [feature]

# %%
y=df["Survived"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler =MinMaxScaler()

# %%
X.head()
# Out:
#    PassengerId  Sex   Age  Pclass  SibSp  Parch     Fare  Embarked
# 0            1    0  22.0       3      1      0   7.2500         0
# 1            2    1  38.0       1      1      0  71.2833         1
# 2            3    1  26.0       3      0      0   7.9250         0
# 3            4    1  35.0       1      1      0  53.1000         0
# 4            5    0  35.0       3      0      0   8.0500         0

# %%
f =X["Fare"]

# %%
f.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
f=scaler.fit_transform(X)

# %%
f.shape
# Out:
# (891, 8)

# %%
d2 = pd.DataFrame(f,columns=feature)

# %%
df.head()
# Out:
#    PassengerId  Sex  Pclass   Age  SibSp  Parch     Fare  Embarked  Survived
# 0            1    0       3  22.0      1      0   7.2500         0         0
# 1            2    1       1  38.0      1      0  71.2833         1         1
# 2            3    1       3  26.0      0      0   7.9250         0         1
# 3            4    1       1  35.0      1      0  53.1000         0         1
# 4            5    0       3  35.0      0      0   8.0500         0         0

# %%
f = df[["Age","Fare"]]

# %%
f=pd.DataFrame(scaler.fit_transform(f),columns=["Age","Fare"])

# %%
f.head()
# Out:
#         Age      Fare
# 0  0.271174  0.014151
# 1  0.472229  0.139136
# 2  0.321438  0.015469
# 3  0.434531  0.103644
# 4  0.434531  0.015713

# %%
X.head()
# Out:
#    PassengerId  Sex   Age  Pclass  SibSp  Parch     Fare  Embarked
# 0            1    0  22.0       3      1      0   7.2500         0
# 1            2    1  38.0       1      1      0  71.2833         1
# 2            3    1  26.0       3      0      0   7.9250         0
# 3            4    1  35.0       1      1      0  53.1000         0
# 4            5    0  35.0       3      0      0   8.0500         0

# %%
f.count
# Out:
# <bound method DataFrame.count of           Age      Fare
# 0    0.271174  0.014151
# 1    0.472229  0.139136
# 2    0.321438  0.015469
# 3    0.434531  0.103644
# 4    0.434531  0.015713
# 5    0.346569  0.016510
# 6    0.673285  0.101229
# 7    0.019854  0.041136
# 8    0.334004  0.021731
# 9    0.170646  0.058694
# 10   0.044986  0.032596
# 11   0.723549  0.051822
# 12   0.246042  0.015713
# 13   0.484795  0.061045
# 14   0.170646  0.015330
# 15   0.685851  0.031230
# 16   0.019854  0.056848
# 17   0.346569  0.025374
# 18   0.384267  0.035134
# 19   0.346569  0.014102
# 20   0.434531  0.050749
# 21   0.421965  0.025374
# 22   0.183212  0.015672
# 23   0.346569  0.069291
# 24   0.095250  0.041136
# 25   0.472229  0.061264
# 26   0.346569  0.014102
# 27   0.233476  0.513342
# 28   0.346569  0.015379
# 29   0.346569  0.015412
# ..        ...       ...
# 861  0.258608  0.022447
# 862  0.597889  0.050610
# 863  0.346569  0.135753
# 864  0.296306  0.025374
# 865  0.522493  0.025374
# ...

# %%
X["Age"]=df["Age"]
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.head()
# Out:
#    PassengerId  Sex   Age  Pclass  SibSp  Parch      Fare  Embarked
# 0            1    0  22.0       3      1      0  0.014151         0
# 1            2    1  38.0       1      1      0  0.139136         1
# 2            3    1  26.0       3      0      0  0.015469         0
# 3            4    1  35.0       1      1      0  0.103644         0
# 4            5    0  35.0       3      0      0  0.015713         0

# %%
X.tail()
# Out:
#      PassengerId  Sex   Age  Pclass  SibSp  Parch      Fare  Embarked
# 886          887    0  27.0       2      0      0  0.025374         0
# 887          888    1  19.0       1      0      0  0.058556         0
# 888          889    1  28.0       3      1      2  0.045771         0
# 889          890    0  26.0       1      0      0  0.058556         1
# 890          891    0  32.0       3      0      0  0.015127         2

# %%
X["Fare"]=df["Fare"]
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.head()
# Out:
#    PassengerId  Sex   Age  Pclass  SibSp  Parch     Fare  Embarked
# 0            1    0  22.0       3      1      0   7.2500         0
# 1            2    1  38.0       1      1      0  71.2833         1
# 2            3    1  26.0       3      0      0   7.9250         0
# 3            4    1  35.0       1      1      0  53.1000         0
# 4            5    0  35.0       3      0      0   8.0500         0

# %%
X.tail()
# Out:
#      PassengerId  Sex   Age  Pclass  SibSp  Parch   Fare  Embarked
# 886          887    0  27.0       2      0      0  13.00         0
# 887          888    1  19.0       1      0      0  30.00         0
# 888          889    1  28.0       3      1      2  23.45         0
# 889          890    0  26.0       1      0      0  30.00         1
# 890          891    0  32.0       3      0      0   7.75         2

# %%
X
# Out:
#      PassengerId  Sex   Age  Pclass  SibSp  Parch      Fare  Embarked
# 0              1    0  22.0       3      1      0    7.2500         0
# 1              2    1  38.0       1      1      0   71.2833         1
# 2              3    1  26.0       3      0      0    7.9250         0
# 3              4    1  35.0       1      1      0   53.1000         0
# 4              5    0  35.0       3      0      0    8.0500         0
# 5              6    0  28.0       3      0      0    8.4583         2
# 6              7    0  54.0       1      0      0   51.8625         0
# 7              8    0   2.0       3      3      1   21.0750         0
# 8              9    1  27.0       3      0      2   11.1333         0
# 9             10    1  14.0       2      1      0   30.0708         1
# 10            11    1   4.0       3      1      1   16.7000         0
# 11            12    1  58.0       1      0      0   26.5500         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=45)

# %%
print( " Train Size ", X_train.shape)
print( " Train Size ", y_train.shape)
print( " Train Size ", X_test.shape)
print( " Train Size ", y_test.shape)
# Out:
#  Train Size  (534, 8)
#  Train Size  (534,)
#  Train Size  (357, 8)
#  Train Size  (357,)

# %%
data = [X_train, X_test]
for dataset in data:
    dataset['relatives'] = dataset['SibSp'] + dataset['Parch']
    dataset.loc[dataset['relatives'] > 0, 'not_alone'] = 0
    dataset.loc[dataset['relatives'] == 0, 'not_alone'] = 1
    dataset['not_alone'] = dataset['not_alone'].astype(int)
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\augus\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\augus\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_train.head()
# Out:
#      PassengerId  Sex   Age  Pclass  SibSp  Parch     Fare  Embarked  \
# 138          139    0  16.0       3      0      0   9.2167         0
# 22            23    1  15.0       3      0      0   8.0292         2
# 353          354    0  25.0       3      1      0  17.8000         0
# 673          674    0  31.0       2      0      0  13.0000         0
# 273          274    0  37.0       1      0      1  29.7000         1
#
#      relatives  not_alone
# 138          0          1
# 22           0          1
# 353          1          0
# 673          0          1
# 273          1          0

# %%
X_train=X_train.drop(['PassengerId'], axis=1)

# %%
data = [X_test, X_train]
for dataset in data:
    dataset['Age_Class']= dataset['Age']* dataset['Pclass']
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for dataset in data:
    dataset['Fare_Per_Person'] = dataset['Fare']/(dataset['relatives']+1)
    dataset['Fare_Per_Person'] = dataset['Fare_Per_Person'].astype(int)
# Let's take a last look at the training set, before we start training the models.
X_train.head(10)
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\augus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Sex   Age  Pclass  SibSp  Parch     Fare  Embarked  relatives  not_alone  \
# 138    0  16.0       3      0      0   9.2167         0          0          1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
index=X_test.PassengerId

# %%
X_test=X_test.drop(['PassengerId'],axis=1)

# %%
p = model.predict(X_test)

# %%
p==y_test
# Out:
# 248    False
# 197     True
# 133     True
# 169    False
# 736     True
# 166     True
# 250     True
# 719     True
# 603    False
# 471     True
# 682     True
# 833     True
# 582     True
# 399     True
# 408    False
# 704     True
# 173     True
# 738     True
# 339     True
# 701     True
# 112     True
# 459     True
# 562    False
# 290     True
# 564     True
# 549     True
# 646     True
# 378    False
# 225     True
# 372    False
#        ...
# 325     True
# 305    False
# 734     True
# 710     True
# 32      True
# 613     True
# 882     True
# 179     True
# 750     True
# 230     True
# 681    False
# 368     True
# 832     True
# 103    False
# 645    False
# 131     True
# 827     True
# 802     True
# 684     True
# 772    False
# 605     True
# 362     True
# 558     True
# 161     True
# 13      True
# 644     True
# 14     False
# 528    False
# 153     True
# 816    False
# Name: Survived, Length: 357, dtype: bool

# %%
scor = [p==y_test]

# %%
print(sum(scor))
# Out:
# 248    0
# 197    1
# 133    1
# 169    0
# 736    1
# 166    1
# 250    1
# 719    1
# 603    0
# 471    1
# 682    1
# 833    1
# 582    1
# 399    1
# 408    0
# 704    1
# 173    1
# 738    1
# 339    1
# 701    1
# 112    1
# 459    1
# 562    0
# 290    1
# 564    1
# 549    1
# 646    1
# 378    0
# 225    1
# 372    0
#       ..
# 325    1
# 305    0
# 734    1
# 710    1
# 32     1
# 613    1
# 882    1
# 179    1
# 750    1
# 230    1
# 681    0
# 368    1
# 832    1
# 103    0
# 645    0
# 131    1
# 827    1
# 802    1
# 684    1
# 772    0
# 605    1
# 362    1
# 558    1
# 161    1
# 13     1
# 644    1
# 14     0
# 528    0
# 153    1
# 816    0
# Name: Survived, Length: 357, dtype: int32

# %%
np.sum(scor)
# Out:
# 281

# %%
281/357
# Out:
# 0.7871148459383753

# %%
 acc_decision_tree = round(model.score(X_train, y_train) * 100, 2)

# %%
 acc_decision_tree
# Out:
# 98.13

# %%
mat = np.arange(0,1600).reshape(40,40)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mat,cmap="rocket")

# %%
help()
# Out:
# Welcome to Python 3.7's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> import antigravity
# No Python documentation found for 'import antigravity'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
